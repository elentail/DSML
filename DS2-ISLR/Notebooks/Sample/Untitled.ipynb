# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sample_credit.csv')

# %%
df.describe()
# Out:
#                Time           V1           V2           V3           V4  \
# count   9999.000000  9999.000000  9999.000000  9999.000000  9999.000000
# mean    5965.128713    -0.241768     0.281829     0.906164     0.263916
# std     4472.712504     1.521726     1.308149     1.159164     1.441120
# min        0.000000   -27.670569   -34.607649   -15.496222    -4.657545
# 25%     2072.500000    -1.013135    -0.208350     0.412752    -0.614489
# 50%     4563.000000    -0.372624     0.288381     0.944342     0.219852
# 75%    10231.500000     1.150869     0.901632     1.602707     1.125501
# max    15010.000000     1.960497     8.636214     4.101716    10.463020
#
#                 V5           V6           V7           V8           V9  \
# count  9999.000000  9999.000000  9999.000000  9999.000000  9999.000000
# mean     -0.046353     0.133134    -0.071791    -0.064802     0.802379
# std       1.182986     1.307373     1.077437     1.259125     1.155150
# ...

# %%
def best_corr(args):
    temp= []
    for i,v in enumerate(args):
        if v<1.0:
            temp.append((i,v))
    temp = sorted(temp ,key=lambda x:x[1])
    idx, corrv = temp[-1]
    return (df.columns[idx],corrv)
        
df.corr().apply(best_corr)
# Out:
# Time           (V13, 0.517629889638993)
# V1           (V25, 0.22996334901096543)
# V2         (Class, 0.16663033721295434)
# V3           (V22, 0.27329779322897857)
# V4         (Class, 0.22948751937596687)
# V5            (V15, 0.1174370759116171)
# V6        (Amount, 0.22074583076826376)
# V7        (Amount, 0.32716969870081736)
# V8            (V1, 0.22989228130013153)
# V9           (Time, 0.4700983725351354)
# V10           (V3, 0.15008142008396147)
# V11          (Time, 0.3762062279983042)
# V12          (V15, 0.17143980062002273)
# V13           (Time, 0.517629889638993)
# V14           (Time, 0.408843579160902)
# V15          (V12, 0.17143980062002273)
# V16          (V14, 0.31090031528722056)
# V17           (V14, 0.3466709877744654)
# V18          (V16, 0.22939124905957597)
# V19          (V18, 0.12335887790774584)
# V20         (Amount, 0.220921174839262)
# V21           (V2, 0.14615304957632333)
# V22           (V3, 0.27329779322897857)
# ...
